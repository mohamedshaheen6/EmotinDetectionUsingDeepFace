# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
img = cv2.imread(r"E:\DS SM\AI\adhm.jpg")

# %%
plt.imshow(img[:,:,::-1])
plt.show()

# %%
emotion = DeepFace.analyze(img,actions=['emotion'])
emotion
# Out:
# 1/1 [==============================] - 0s 390ms/step
# {'emotion': {'angry': 0.20290720185998656,
#   'disgust': 6.440587099695557e-05,
#   'fear': 0.08546313765525668,
#   'happy': 0.9523183834769269,
#   'sad': 91.76104166972141,
#   'surprise': 0.00017281528457602238,
#   'neutral': 6.998026281830516},
#  'dominant_emotion': 'sad',
#  'region': {'x': 463, 'y': 218, 'w': 208, 'h': 208}}

# %%
print(emotion['dominant_emotion'])
# Out:
# sad

# %%
img2=cv2.imread(r"E:\DS SM\AI\man.jpg")

# %%
plt.imshow(img2[:,:,::-1])
plt.show()

# %%
emotion2 = DeepFace.analyze(img2,actions=['emotion'])
print(emotion2['dominant_emotion'])
# Out:
# 1/1 [==============================] - 0s 31ms/step
# happy
